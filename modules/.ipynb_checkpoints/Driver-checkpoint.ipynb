# %%
from kmeans import kmeans
from sklearn.datasets.samples_generator import make_blobs
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
    X = make_blobs(n_samples=200, centers=4, cluster_std=0.60, random_state=0)
    X = X[0]
    plt.scatter(X[:, 0], X[:, 1])

# %%
alg = kmeans()
for x in alg.fit(X):
    asser x in X
# Out:
# [[0.170847764650771, 0.22701911135151553, 0.406121910431005], [0.5008724160825092, 0.45441611306035123, 0.6092627748002332], [0.47937080530846676, 0.5709435751363572, 0.6103012866409888], [0.6377127933500404, 0.6813462308816564, 0.41105054657472917], [0.6377127933500404, 0.6813462308816564, 0.41105054657472917]]
